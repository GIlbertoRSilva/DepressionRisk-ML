# %% [markdown]
# # 02 — Pré-Processamento
#
# Este notebook demonstra o processo completo de pré-processamento aplicado ao dataset bruto, baseado nas decisões tomadas na Análise Exploratória (01_EDA.ipynb). Ele utiliza o arquivo `preprocess.py`, que contém o pipeline oficial do projeto.

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from src import preprocess as pp

RAW_PATH = "../data/raw/student_depression_dataset.csv"

# %% [markdown]
# Dataset

# %%
df_raw = pd.read_csv(RAW_PATH)
print("Shape inicial:", df_raw.shape)
df_raw.head()
# Out:
# Shape inicial: (27901, 18)
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %% [markdown]
# Valores inconsistentes

# %%
inconsistent_values = [
    "Other", "Others", "?", "Unknown",
    "Prefer not to say", " ", "", "NA",
    "N/A", "None"
]

print("Buscando valores inconsistentes...")

for col in df_raw.columns:
    unq = df_raw[col].astype(str).unique()
    bad = [v for v in unq if v in inconsistent_values]
    if bad:
        print(f" - {col}: {bad}")
# Out:
# Buscando valores inconsistentes...
#  - Sleep Duration: ['Others']
#  - Dietary Habits: ['Others']
#  - Degree: ['Others']
#  - Financial Stress: ['?']

# %% [markdown]
# Remover amostras com valores inconsistentes

# %%
df_clean = pp.remove_rows_with_inconsistent_values(df_raw)

print("Shape após remover inconsistentes:", df_clean.shape)
df_clean.head()
# Out:
# Shape após remover inconsistentes: (27833, 18)
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %% [markdown]
# Remover colunas irrelevantes

# %%
df_clean = pp.remove_irrelevant_columns(df_clean)

print("Shape após remover colunas irrelevantes:", df_clean.shape)
df_clean.head()
# Out:
# Removendo colunas que não serão usadas no modelo.
# Shape após remover colunas irrelevantes: (27833, 12)
#    Gender   Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0    Male  33.0                5.0  8.97                 2.0
# 1  Female  24.0                2.0  5.90                 5.0
# 2    Male  31.0                3.0  7.03                 5.0
# 3  Female  28.0                3.0  5.59                 2.0
# 4  Female  25.0                4.0  8.13                 3.0
#
#         Sleep Duration Dietary Habits Have you ever had suicidal thoughts ?  \
# 0          '5-6 hours'        Healthy                                   Yes
# 1          '5-6 hours'       Moderate                                    No
# 2  'Less than 5 hours'        Healthy                                    No
# 3          '7-8 hours'       Moderate                                   Yes
# 4          '5-6 hours'       Moderate                                   Yes
#
#    Work/Study Hours Financial Stress Family History of Mental Illness  \
# 0               3.0              1.0                               No
# 1               3.0              2.0                              Yes
# 2               9.0              1.0                              Yes
# 3               4.0              5.0                              Yes
# 4               1.0              1.0                               No
#
#    Depression
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# Tratar valores categóricos

# %%
df_clean = pp.treat_values(df_clean)

df_clean.head()
# Out:
# Tratando valores do dataset
#    Gender   Age  Academic Pressure  CGPA  Study Satisfaction  Sleep Duration  \
# 0       0  33.0                5.0  8.97                 2.0             5.5
# 1       1  24.0                2.0  5.90                 5.0             5.5
# 2       0  31.0                3.0  7.03                 5.0             4.0
# 3       1  28.0                3.0  5.59                 2.0             7.5
# 4       1  25.0                4.0  8.13                 3.0             5.5
#
#    Dietary Habits  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0               2                                      1               3.0
# 1               1                                      0               3.0
# 2               2                                      0               9.0
# 3               1                                      1               4.0
# 4               1                                      1               1.0
#
#   Financial Stress  Family History of Mental Illness  Depression
# 0              1.0                                 0           1
# 1              2.0                                 1           0
# 2              1.0                                 1           0
# 3              5.0                                 1           1
# 4              1.0                                 0           0

# %% [markdown]
# Filtrar faixas etárias inválidas

# %%
df_clean = pp.filter_age(df_clean)

print("Shape após filtrar idade:", df_clean.shape)
df_clean["Age"].describe()
# Out:
# Filtrando idades
# Shape após filtrar idade: (27822, 12)
# count    27822.000000
# mean        25.809827
# std          4.880406
# min         18.000000
# 25%         21.000000
# 50%         25.000000
# 75%         30.000000
# max         44.000000
# Name: Age, dtype: float64

# %% [markdown]
# Remover valores faltantes restantes

# %%
df_clean = pp.drop_missing(df_clean)

print("Shape após drop de NA:", df_clean.shape)
df_clean.isna().sum()
# Out:
# Shape após drop de NA: (27822, 12)
# Gender                                   0
# Age                                      0
# Academic Pressure                        0
# CGPA                                     0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# Salvar Dataset Limpo

# %%
processed_path = Path("../data/processed")
processed_path.mkdir(parents=True, exist_ok=True)

output_file = processed_path / "cleaned_student_dataset.csv"
df_clean.to_csv(output_file, index=False)

print(f"Dataset final salvo em: {output_file}")
# Out:
# Dataset final salvo em: ../data/processed/cleaned_student_dataset.csv

# %%
pp.split_data(df_clean)
# Out:
# 📁 Arquivos de treino e teste gerados com sucesso!
# 📁 Arquivos de treino e teste gerados com sucesso!
# (       Gender   Age  Academic Pressure  CGPA  Study Satisfaction  \
#  13440       1  23.0                5.0  8.52                 5.0
#  8791        1  19.0                1.0  9.44                 5.0
#  21125       0  21.0                1.0  6.92                 4.0
#  15973       0  31.0                4.0  6.27                 3.0
#  10251       1  25.0                5.0  9.91                 3.0
#  ...       ...   ...                ...   ...                 ...
#  7019        0  30.0                1.0  6.37                 3.0
#  7050        1  25.0                3.0  8.21                 3.0
#  9251        0  24.0                4.0  9.74                 2.0
#  14205       0  31.0                4.0  5.70                 1.0
#  16607       1  26.0                3.0  7.08                 3.0
#
#         Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
#  13440             5.5               1                                      0
#  8791              7.5               0                                      1
#  21125             4.0               1                                      0
#  15973             9.0               0                                      1
#  10251             4.0               0                                      1
#  ...               ...             ...                                    ...
#  7019              5.5               2                                      0
#  7050              5.5               2                                      1
#  9251              4.0               1                                      0
#  14205             7.5               2                                      0
#  16607             7.5               0                                      1
#
#         Work/Study Hours Financial Stress  Family History of Mental Illness  \
#  13440               5.0              1.0                                 0
#  8791               11.0              5.0                                 1
#  21125               6.0              2.0                                 1
#  15973               0.0              4.0                                 1
#  10251               9.0              3.0                                 0
#  ...                 ...              ...                               ...
#  7019                0.0              2.0                                 0
#  7050                6.0              3.0                                 1
#  9251                7.0              4.0                                 1
#  14205              11.0              5.0                                 0
#  16607              12.0              3.0                                 0
#
#         Depression
#  13440           0
#  8791            1
#  21125           0
#  15973           1
#  10251           1
#  ...           ...
#  7019            0
#  7050            1
#  9251            1
#  14205           1
#  16607           1
#
#  [22257 rows x 12 columns],
#         Gender   Age  Academic Pressure  CGPA  Study Satisfaction  \
#  21832       0  32.0                3.0  7.52                 2.0
#  5920        0  25.0                3.0  8.88                 2.0
#  21459       0  25.0                3.0  8.62                 3.0
#  35          1  25.0                1.0  6.37                 3.0
#  742         0  31.0                1.0  8.04                 4.0
#  ...       ...   ...                ...   ...                 ...
#  14607       1  24.0                3.0  8.03                 1.0
#  12406       0  29.0                2.0  9.96                 3.0
#  1326        0  25.0                3.0  7.88                 5.0
#  5041        0  23.0                2.0  9.43                 5.0
#  5975        1  33.0                3.0  9.71                 4.0
#
#         Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
#  21832             5.5               1                                      1
#  5920              7.5               1                                      1
#  21459             5.5               2                                      1
#  35                7.5               1                                      1
#  742               5.5               2                                      1
#  ...               ...             ...                                    ...
#  14607             4.0               2                                      0
#  12406             9.0               1                                      0
#  1326              5.5               2                                      1
#  5041              9.0               1                                      1
#  5975              9.0               2                                      1
#
#         Work/Study Hours Financial Stress  Family History of Mental Illness  \
#  21832               8.0              2.0                                 0
#  5920                1.0              1.0                                 1
#  21459               9.0              4.0                                 1
#  35                  2.0              2.0                                 0
#  742                 2.0              3.0                                 0
#  ...                 ...              ...                               ...
#  14607               8.0              5.0                                 0
#  12406              12.0              3.0                                 0
#  1326                7.0              3.0                                 1
#  5041                8.0              1.0                                 1
#  5975                1.0              3.0                                 1
#
#         Depression
#  21832           1
#  5920            0
#  21459           0
#  35              0
#  742             0
#  ...           ...
#  14607           1
#  12406           0
#  1326            1
#  5041            0
#  5975            0
#
#  [5565 rows x 12 columns])

# %% [markdown]
# # Conclusão
#
# O pré-processamento foi concluído com sucesso.
#
# - Valores inconsistentes removidos
# - Colunas irrelevantes excluídas
# - Valores categóricos mapeados
# - Idades fora da faixa filtradas
# - Dataset final salvo em `data/processed/dataset_final.csv`
#
# Este dataset será utilizado agora no notebook **03_Model_Training.ipynb**
